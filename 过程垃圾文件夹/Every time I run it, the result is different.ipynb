# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
Mit = 1
Kit = 506068796
Cit = 0.2
Fit = 45
def diff(y,t):
    yt, theta = y
    return theta , (Fit-Kit*yt-Cit*theta)/Mit
y0 = [0,0]

T_0 = 2.79*10**-4
# dt  = 2.79*10**-5
# dt1 = T_0/20
dt1 = 1.2*T_0/5
t = np.arange(0,10*T_0,dt1)

sol = odeint(diff, y0, t) 
plt.plot(t,sol)
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
sol.shape
# t = np.linspace(0, 1.76, 496)
# t = np.linspace(0, 2, 596)
# t = np.linspace(0, 2, 71685)
# t = np.linspace(0,2.79*10**-3, int(2.79*10**-3/(2.79*10**-5)) )
# Out:
# (2792, 2)

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
Mit = 1
Kit = 50 #6068796
Cit = 0.2
Fit = 45
def diff(y,t):
    yt, theta = y
    return theta , (Fit-Kit*yt-Cit*theta)/Mit
y0 = [0,0]

T_0 = 2*np.pi*np.sqrt(Mit/Kit)
# dt  = 2.79*10**-5
# dt1 = T_0/20
dt1 = 1.2*T_0/5
t = np.arange(0,10*T_0,dt1)

sol = odeint(diff, y0, t) 
plt.plot(t,sol[:,0])
# plt.plot(t,sol[:,1])



plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
def func(x):
    y = np.exp(-0.1*x) * ( -45*np.cos(7.07*x)-0.6365*np.sin(7.07*x))+45
    return y
plt.plot(t,func(t),label="exact")
plt.legend()
